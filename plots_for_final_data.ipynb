# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
mycolors = ['tab:green', 'tab:blue', 'tab:red']

# %%
#adding path to file
PATH_sim1 = "ecosystem/lot_of_trees.csv"
df_sim1 = pd.read_csv(PATH_sim1)
df_sim1['Year'] = df_sim1.index
df_sim1
# Out:
#      Spruce (count)  Spruce volume (m^3)  Fir (count)  Fir volume (m^3)  \
# 0               207         1.979663e+08           62      1.292658e+08
# 1               210         2.013548e+08           63      1.309782e+08
# 2               211         2.047384e+08           63      1.326602e+08
# 3               214         2.081497e+08           63      1.343200e+08
# 4               216         2.115534e+08           64      1.359705e+08
# ..              ...                  ...          ...               ...
# 295            2605         1.275783e+09          646      4.622808e+08
# 296            2629         1.283316e+09          655      4.661505e+08
# 297            2655         1.290872e+09          661      4.664236e+08
# 298            2653         1.298090e+09          661      4.701478e+08
# 299            2688         1.305690e+09          666      4.739333e+08
#
#      Beech (count)  Beech volume (m^3)  Year
# 0              410        3.597858e+09     0
# 1              412        3.666706e+09     1
# 2              417        3.735864e+09     2
# 3              420        3.805203e+09     3
# 4              424        3.874731e+09     4
# ..             ...                 ...   ...
# 295           5804        1.452214e+10   295
# 296           5862        1.462180e+10   296
# 297           5916        1.469041e+10   297
# 298           5915        1.475815e+10   298
# 299           5967        1.485717e+10   299
#
# [300 rows x 7 columns]

# %%
#preparing data for plots
x_sim1  = df_sim1['Year'].values.tolist()

y1_sim1 = df_sim1['Spruce (count)'].values.tolist()
y2_sim1 = df_sim1['Fir (count)'].values.tolist()
y3_sim1 = df_sim1['Beech (count)'].values.tolist()
y_1_sim1 = np.vstack([y1_sim1, y2_sim1, y3_sim1])

y4_sim1 = df_sim1['Spruce volume (m^3)'].values.tolist()
y5_sim1 = df_sim1['Fir volume (m^3)'].values.tolist()
y6_sim1 = df_sim1['Beech volume (m^3)'].values.tolist()
y_2_sim1 = np.vstack([y4_sim1, y5_sim1, y6_sim1])

# %%
#adding path to file
PATH_sim2 = "ecosystem/extreme_weather.csv"
df_sim2 = pd.read_csv(PATH_sim2)
df_sim2['Year'] = df_sim2.index
df_sim2
# Out:
#      Spruce (count)  Spruce volume (m^3)  Fir (count)  Fir volume (m^3)  \
# 0               175         1.615106e+08           61      1.438793e+08
# 1               175         1.641696e+08           61      1.453105e+08
# 2               175         1.668360e+08           61      1.467220e+08
# 3               175         1.695027e+08           61      1.481130e+08
# 4               175         1.702195e+08           61      1.484746e+08
# ..              ...                  ...          ...               ...
# 295             171         3.297643e+08           26      5.646691e+07
# 296             171         3.297758e+08           26      5.646974e+07
# 297             171         3.299636e+08           26      5.651592e+07
# 298             170         3.268794e+08           26      5.651845e+07
# 299             169         3.236353e+08           26      5.651918e+07
#
#      Beech (count)  Beech volume (m^3)  Year
# 0              477        3.941896e+09     0
# 1              477        4.023337e+09     1
# 2              477        4.105271e+09     2
# 3              477        4.187519e+09     3
# 4              476        4.203288e+09     4
# ..             ...                 ...   ...
# 295            518        9.432614e+09   295
# 296            518        9.432863e+09   296
# 297            517        9.405996e+09   297
# 298            514        9.327984e+09   298
# 299            513        9.327688e+09   299
#
# [300 rows x 7 columns]

# %%
#preparing data for plots
x_sim2  = df_sim2['Year'].values.tolist()

y1_sim2 = df_sim2['Spruce (count)'].values.tolist()
y2_sim2 = df_sim2['Fir (count)'].values.tolist()
y3_sim2 = df_sim2['Beech (count)'].values.tolist()
y_1_sim2 = np.vstack([y1_sim2, y2_sim2, y3_sim2])

y4_sim2 = df_sim2['Spruce volume (m^3)'].values.tolist()
y5_sim2 = df_sim2['Fir volume (m^3)'].values.tolist()
y6_sim2 = df_sim2['Beech volume (m^3)'].values.tolist()
y_2_sim2 = np.vstack([y4_sim2, y5_sim2, y6_sim2])

# %%
#plots for first simulation
fig, ax = plt.subplots(figsize=(16, 9))
columns = df_sim1.columns[1:]
labs = columns.values.tolist()
ax = plt.gca()
ax.stackplot(x_sim1, y_1_sim1, labels=['Spruce','Fir','Beech'], colors=mycolors, alpha=0.8)
ax.set_title('Total number of trees (lots o\' trees)', fontsize=18)
ax.legend(fontsize=10, ncol=3)
plt.xticks(x_sim1[::int((max(x_sim1)+1)/10)], fontsize=10, horizontalalignment='center')
plt.xticks(fontsize=10)
plt.xlim(x_sim1[0], x_sim1[-1])
ax.set_xlabel('Time (year)')
ax.set_ylabel('Number of trees (trunk)')
plt.savefig('lots_of_trees_count.png') 

fig, ax = plt.subplots(figsize=(16, 9))
columns = df_sim1.columns[1:]
labs = columns.values.tolist()
ax = plt.gca()
ax.stackplot(x_sim1, y_2_sim1, labels=['Spruce','Fir','Beech'], colors=mycolors, alpha=0.8)
ax.set_title('Total volume of trees (lots o\' trees)', fontsize=18)
ax.legend(fontsize=10, ncol=3)
plt.xticks(x_sim1[::int((max(x_sim2)+1)/10)], fontsize=10, horizontalalignment='center')
plt.xticks(fontsize=10)
plt.xlim(x_sim1[0], x_sim1[-1])
ax.set_xlabel('Time (year)')
ax.set_ylabel('Volume of trees (m^3)')
plt.savefig('lots_of_trees_volume.png') 

#plots for second simulation
fig, ax = plt.subplots(figsize=(16, 9))
columns = df_sim2.columns[1:]
labs = columns.values.tolist()
ax = plt.gca()
ax.stackplot(x_sim2, y_1_sim2, labels=['Spruce','Fir','Beech'], colors=mycolors, alpha=0.8)
ax.set_title('Total number of trees (extreme weather)', fontsize=18)
ax.legend(fontsize=10, ncol=3)
plt.xticks(x_sim2[::int((max(x_sim2)+1)/10)], fontsize=10, horizontalalignment='center')
plt.xticks(fontsize=10)
plt.xlim(x_sim2[0], x_sim2[-1])
ax.set_xlabel('Time (year)')
ax.set_ylabel('Number of trees (trunk)')
plt.savefig('extreme_weather_count.png') 

fig, ax = plt.subplots(figsize=(16, 9))
columns = df_sim2.columns[1:]
labs = columns.values.tolist()
ax = plt.gca()
ax.stackplot(x_sim2, y_2_sim2, labels=['Spruce','Fir','Beech'], colors=mycolors, alpha=0.8)
ax.set_title('Total volume of trees (extreme weather)', fontsize=18)
ax.legend(fontsize=10, ncol=3)
plt.xticks(x_sim2[::int((max(x_sim2)+1)/10)], fontsize=10, horizontalalignment='center')
plt.xticks(fontsize=10)
plt.xlim(x_sim2[0], x_sim2[-1])
ax.set_xlabel('Time (year)')
ax.set_ylabel('Volume of trees (m^3)')
plt.savefig('extreme_weather_volume.png') 

plt.show()
