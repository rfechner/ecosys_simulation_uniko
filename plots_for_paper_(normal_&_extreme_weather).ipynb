# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
mycolors = ['tab:green', 'tab:blue', 'tab:red']

# %%
#adding path to file
PATH_sim1 = "paper_resources/paper_normal.csv"
df_sim1 = pd.read_csv(PATH_sim1, comment='#')
df_sim1['Year'] = df_sim1.index
df_sim1
# Out:
#      Spruce (count)  Spruce volume (m^3)  Fir (count)  Fir volume (m^3)  \
# 0               199         1.951725e+08           53      1.231148e+08
# 1               199         1.942504e+08           53      1.219926e+08
# 2               199         1.943836e+08           53      1.231574e+08
# 3               197         1.906370e+08           48      1.052842e+08
# 4               196         1.926579e+08           46      9.924318e+07
# ..              ...                  ...          ...               ...
# 495            9855         1.893240e+09            0      1.664739e-07
# 496            9947         1.899824e+09            0      1.664739e-07
# 497           10038         1.907648e+09            0      1.664739e-07
# 498           10114         1.910740e+09            0      1.664739e-07
# 499           10183         1.906561e+09            0      1.664739e-07
#
#      Beech (count)  Beech volume (m^3)  Year
# 0              490        3.846920e+09     0
# 1              491        3.894913e+09     1
# 2              493        3.833760e+09     2
# 3              502        3.875372e+09     3
# 4              509        3.902208e+09     4
# ..             ...                 ...   ...
# 495          10268        7.936151e+09   495
# 496          10335        7.868081e+09   496
# 497          10400        7.848226e+09   497
# 498          10470        7.861474e+09   498
# 499          10560        7.899930e+09   499
#
# [500 rows x 7 columns]

# %%
#preparing data for plots
x_sim1  = df_sim1['Year'].values.tolist()

y1_sim1 = df_sim1['Spruce (count)'].values.tolist()
y2_sim1 = df_sim1['Fir (count)'].values.tolist()
y3_sim1 = df_sim1['Beech (count)'].values.tolist()
y_1_sim1 = np.vstack([y1_sim1, y2_sim1, y3_sim1])

y4_sim1 = df_sim1['Spruce volume (m^3)'].values.tolist()
y5_sim1 = df_sim1['Fir volume (m^3)'].values.tolist()
y6_sim1 = df_sim1['Beech volume (m^3)'].values.tolist()
y_2_sim1 = np.vstack([y4_sim1, y5_sim1, y6_sim1])

# %%
#adding path to file
PATH_sim2 = "paper_resources/paper_extreme_weather.csv"
df_sim2 = pd.read_csv(PATH_sim2, comment='#')
df_sim2['Year'] = df_sim2.index
df_sim2
# Out:
#      Spruce (count)  Spruce volume (m^3)  Fir (count)  Fir volume (m^3)  \
# 0               187         1.961215e+08           43      9.316483e+07
# 1               189         1.975689e+08           39      8.607069e+07
# 2               188         1.958948e+08           41      8.702139e+07
# 3               186         1.966963e+08           40      8.437378e+07
# 4               187         1.978446e+08           40      7.920435e+07
# ..              ...                  ...          ...               ...
# 495               2         6.423525e+06            0      3.958121e-08
# 496               2         6.442787e+06            0      3.958121e-08
# 497               2         6.461595e+06            0      3.958121e-08
# 498               2         6.479959e+06            0      3.958121e-08
# 499               2         6.497888e+06            0      3.958121e-08
#
#      Beech (count)  Beech volume (m^3)  Year
# 0              467        3.627039e+09     0
# 1              471        3.660720e+09     1
# 2              472        3.663749e+09     2
# 3              466        3.683270e+09     3
# 4              470        3.711872e+09     4
# ..             ...                 ...   ...
# 495             10        1.835627e+08   495
# 496             10        1.843772e+08   496
# 497             10        1.851801e+08   497
# 498             10        1.859714e+08   498
# 499             10        1.867512e+08   499
#
# [500 rows x 7 columns]

# %%
#preparing data for plots
x_sim2  = df_sim2['Year'].values.tolist()

y1_sim2 = df_sim2['Spruce (count)'].values.tolist()
y2_sim2 = df_sim2['Fir (count)'].values.tolist()
y3_sim2 = df_sim2['Beech (count)'].values.tolist()
y_1_sim2 = np.vstack([y1_sim2, y2_sim2, y3_sim2])

y4_sim2 = df_sim2['Spruce volume (m^3)'].values.tolist()
y5_sim2 = df_sim2['Fir volume (m^3)'].values.tolist()
y6_sim2 = df_sim2['Beech volume (m^3)'].values.tolist()
y_2_sim2 = np.vstack([y4_sim2, y5_sim2, y6_sim2])

# %%
#plots for first simulation
fig, ax = plt.subplots(figsize=(16, 9))
columns = df_sim1.columns[1:]
labs = columns.values.tolist()
ax = plt.gca()
ax.stackplot(x_sim1, y_1_sim1, labels=['Spruce','Fir','Beech'], colors=mycolors, alpha=0.8)
ax.set_title('Total number of trees (normal conditions)', fontsize=18)
ax.legend(fontsize=15, ncol=1, bbox_to_anchor=(1.002, 1), loc='upper left', borderaxespad=0.)
plt.xticks(x_sim1[::int((max(x_sim1)+1)/10)], fontsize=15, horizontalalignment='center')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlim(x_sim1[0], x_sim1[-1])
ax.set_xlabel('Time (year)',fontsize=15)
ax.set_ylabel('Number of trees (trunk)',fontsize=15)
plt.savefig('paper_resources/paper_normal_count.png') 

fig, ax = plt.subplots(figsize=(16, 9))
columns = df_sim1.columns[1:]
labs = columns.values.tolist()
ax = plt.gca()
ax.stackplot(x_sim1, y_2_sim1, labels=['Spruce','Fir','Beech'], colors=mycolors, alpha=0.8)
ax.set_title('Total volume of trees (normal conditions)', fontsize=18)
ax.legend(fontsize=15, ncol=1, bbox_to_anchor=(1.002, 1), loc='upper left', borderaxespad=0.)
plt.xticks(x_sim1[::int((max(x_sim2)+1)/10)], fontsize=15, horizontalalignment='center')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlim(x_sim1[0], x_sim1[-1])
ax.set_xlabel('Time (year)',fontsize=15)
ax.set_ylabel('Volume of trees (m^3)',fontsize=15)
plt.savefig('paper_resources/paper_normal_volume.png') 

#plots for second simulation
fig, ax = plt.subplots(figsize=(16, 9))
columns = df_sim2.columns[1:]
labs = columns.values.tolist()
ax = plt.gca()
ax.stackplot(x_sim2, y_1_sim2, labels=['Spruce','Fir','Beech'], colors=mycolors, alpha=0.8)
ax.set_title('Total number of trees (extreme weather)', fontsize=18)
ax.legend(fontsize=15, ncol=1, bbox_to_anchor=(1.002, 1), loc='upper left', borderaxespad=0.)
plt.xticks(x_sim2[::int((max(x_sim2)+1)/10)], fontsize=20, horizontalalignment='center')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlim(x_sim2[0], x_sim2[-1])
ax.set_xlabel('Time (year)',fontsize=15)
ax.set_ylabel('Number of trees (trunk)',fontsize=15)
plt.savefig('paper_resources/paper_extreme_weather_count.png') 

fig, ax = plt.subplots(figsize=(16, 9))
columns = df_sim2.columns[1:]
labs = columns.values.tolist()
ax = plt.gca()
ax.stackplot(x_sim2, y_2_sim2, labels=['Spruce','Fir','Beech'], colors=mycolors, alpha=0.8)
ax.set_title('Total volume of trees (extreme weather)', fontsize=18)
ax.legend(fontsize=15, ncol=1, bbox_to_anchor=(1.002, 1), loc='upper left', borderaxespad=0.)
plt.xticks(x_sim2[::int((max(x_sim2)+1)/10)], fontsize=15, horizontalalignment='center')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlim(x_sim2[0], x_sim2[-1])
ax.set_xlabel('Time (year)',fontsize=15)
ax.set_ylabel('Volume of trees (m^3)',fontsize=15)
plt.savefig('paper_resources/paper_extreme_weather_volume.png') 

plt.show()
